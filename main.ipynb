# %% [markdown]
# # Main

# %%
# Importing libraries
import os
import numpy as np
import pandas as pd
import sisl as si
import phonopy as ph
import matplotlib.pyplot as plt
# ASE modules
from ase import Atoms
from ase.calculators.siesta import Siesta
from ase.units import Ry
from ase.visualize import view
from ase.io import read, write
from ase.dft.kpoints import bandpath
# Path module
from pathlib import Path
# Matplotlib ticker
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
# Custom modules
#from codes.bulkBS import calcBS, calcPDOS
from src.cleanfiles import cleanFiles
from src.utils import SiestaProject
from src.structure import Perovskite
from src.parameterconv import run_siesta, basis_opt, grid_conv
from src.structureoptimizer import relax_ase, relax_siesta
from src.bandscalc import calculate_bands, plot_bands, plot_bands2
from src.phononcalc import calculate_phonons, plot_dispersion, plot_dispersion2
from src.plotsettings import PlotSettings
PlotSettings().set_global_style()

# %% [markdown]
# ## Contents
# This notebook contains the following sections:
#
# 0. [Pseudopotentials and basis functions](#pseudo)
# 1. [Basis set optimization](#basisset)
# 2. [Real-space grid optimization](#spacegrid)
# 3. [Structural optimization (bulk)](#structureopt)
# 4. [Band structure and DOS (bulk)](#bands)
# 5. [Phonon dispersion (bulk)](#phonons)

# %% [markdown]
# <a id="pseudo"></a>
# ## 0. Pseudopotentials and basis functions

# %% [markdown]
# The main input of SIESTA are the pseudpotential files (.psml or .psf).\
# In DFT we do not explicitly treat:
# - tightly bound core electrons
# - the nuclear Coulomb singularity
#
# Instead, we replace nucleus + core electrons with an effective/pseudo potential acting on valence electrons.
#
# We do this becouse core electrons:
# - are chemically inert
# - do not participate in bonding
# - oscillate very rapidly near the nucleus
# - require huge basis sets if treated explicitly
#
# Removing them:
# - makes calculations much cheaper
# - keeps valence physics intact
#
# When generating a pseudopotential, it is a decision about (valence configuration):
# - which electrons are treated as valence
# - which are frozen into the core

# %% [markdown]
# Pseudopotentials have been obtained from: https://www.pseudo-dojo.org/
#
# The valence has been choosen as follows (same as in GPAW):
# - Ba: 5s² 5p⁶ 6s² (valence = 10)
# - Sr: 4s² 4p⁶ 5s² (valence = 10)
# - Ti: 3s² 3p⁶ 3d² 4s² (valence = 12)
# - O: 2s² 2p⁴ (valence = 6)

# %%
BaTiO3 = Perovskite('BaTiO3', a=4.00, N=3.5, bulk=False)
BaTiO3

# %%
relax_ase(BaTiO3, basis='test', MeshCutoff=200, kgrid=(4,4,4))

# %%
sile = si.get_sile('resultsold/test/BaTiO3.fdf')
H = sile.read_hamiltonian()
# Create a short-hand to handle the geometry
geom = H.geometry
print(H)

# %%
def plot_atom(atom):
    no = len(atom) # number of orbitals
    nx = no // 4
    ny = no // nx
    if nx * ny < no:
        nx += 1
    fig, axs = plt.subplots(nx, ny, figsize=(20, 5*nx))
    fig.suptitle('Atom: {}'.format(atom.symbol), fontsize=14)
    def my_plot(i, orb):
        grid = orb.toGrid(atom=atom, R=1)
        # Also write to a cube file
        #grid.write('{}_{}.cube'.format(atom.symbol, orb.name()))
        c, r = divmod(i, ny)
        if nx == 1:
            ax = axs[r]
        else:
            ax = axs[c][r]
        ax.imshow(grid.grid[:, :, grid.shape[2] // 2])
        ax.set_title(r'${}$'.format(orb.name(True)))
        ax.set_xlabel(r'$x$ [Ang]')
        ax.set_ylabel(r'$y$ [Ang]')
    i = 0
    for orb in atom:
        my_plot(i, orb)
        i += 1
    if i < nx * ny:
        # This removes the empty plots
        for j in range(i, nx * ny):
            c, r = divmod(j, ny)
            if nx == 1:
                ax = axs[r]
            else:
                ax = axs[c][r]
            fig.delaxes(ax)
        plt.draw()
plot_atom(geom.atoms[0])
plot_atom(geom.atoms[1])
plot_atom(geom.atoms[2])

# %% [markdown]
# <a id="basisset"></a>
# ## 1. Basis set optimization

# %% [markdown]
# Although the default basis sets generated by SIESTA might be enough for some applications, we start by doing some optimization of the basis sets, which can help achieve better results with similar computational costs.

# %% [markdown]
# We have 2 main parameters which allow rough control of the basis set quality:
# - EnergyShift: Controls cut-off radii of the first-zeta orbitals: the lower the energy shift, the larger the cut-off radii.
# - SplitNorm: Controls matching radii of the multiple-zeta orbitals: the lower the value, the larger the matching radii.

# %%
BaTiO3 = perovskite('BaTiO3')
view(BaTiO3)

# %%
# Extract total Energy
stdsile = si.io.siesta.stdoutSileSiesta('results/bulk/basis/BaTiO3.out')
Energies = stdsile.read_energy()
Etot = Energies['total']
print(f'Total Energy: {Etot:.3f} eV')
# Extract Forces
FAsile = si.get_sile('results/bulk/basis/BaTiO3.FA')
Forces = FAsile.read_force()
max_force = max(np.linalg.norm(f) for f in Forces)
print(f'Maximum Force: {max_force} eV/Å')
# Extract lattice constants
xvsile = si.get_sile('results/bulk/basis/BaTiO3.XV')
lat = xvsile.read_geometry().lattice
a = lat.length[0]
b = lat.length[1]
c = lat.length[2]
print(f'Lattice Constants: a={a:.3f} Å, b={b:.3f} Å, c={c:.3f} Å')
# Extract bandgap at the Gamma point
eig = si.get_sile("results/bulk/basis/BaTiO3.EIG").read_data()
Ef = Energies['fermi']
eig -= Ef
eig = eig.flatten()
VBM = eig[eig <= 0].max()
CBM = eig[eig > 0].min()
bandgap = CBM - VBM
print(f'Bandgap at Gamma: {bandgap:.3f} eV')

# %%
stdsile.read_energy()['total']

# %%
si.get_sile(f'results/bulk/basis/BaTiO3.FA').read_force()

# %%
si.io.siesta.structSileSiesta('results/bulk/basis/BaTiO3.STRUCT_OUT').read_geometry()

# %%
si.io.siesta.xvSileSiesta('results/bulk/basis/BaTiO3.XV').read_geometry().lattice

# %%
sile = si.io.siesta.stdoutSileSiesta('results/bulk/basis/BaTiO3.out')
sile.read_energy()

# %%
# This will run the basisoptimization script
# Note: This will take a long time to run on local, use cluster
#%run scripts/basis.py

# %%
df = pd.read_csv('results/bulk/BaTiO3/basis/basisopt.csv')
df.tail()

# %%
import matplotlib.pyplot as plt

def plot_lines(df, xaxis='SplitNorm', yaxis='Enthalpy'):
    # Find the column that is not xaxis to group by
    cols = df.columns[0:2]
    # If there is a 'kgrid' column, we need to handle it differently
    if 'kgrid' in cols:
        # Convert in dataframe to int for plotting only internally in the function, we don't want to modify the original dataframe
        df = df.copy()
        df['kgrid'] = df['kgrid'].apply(lambda x: int(x.split(',')[0].strip('()')))
    
    group_col = [col for col in cols if col != xaxis][0]

    # Figure 1 - yaxis vs xaxis for different values of group_col
    fig = plt.figure(figsize=[6, 5])
    ax = fig.add_subplot(111)
    # Plotting
    for val, data in df.groupby(group_col):
        x = data[xaxis]
        y = data[yaxis]
        # Subtract the first value of y
        y -= y.iloc[0]
        y = y*1000
        ax.plot(x, y, marker='o', label=f'{group_col}={val}')
    # Add x- and y-labels
    ax.set_xlabel(xaxis)
    if yaxis == 'MaxForce':
        label = r'$\Delta$ ' + yaxis + r' (meV/Å)'
    else:
        label = r'$\Delta$ ' + yaxis + r' (meV)'
    ax.set_ylabel(label)
    # Add legend
    ax.legend()
    # Apply custom plot settings to the axes
    PlotSettings().set_style_ax(ax, gridlines=True)
    # Show the plot using tight layout
    plt.tight_layout()
    plt.show()

def plot_contour(df, vals='Enthalpy'):
    # Figure 2 - Contour plot of yaxis as a function of xaxis and group_col
    cols = df.columns[0:2]
    Z = df.pivot(index=cols[0], columns=cols[1], values=vals)
    Z -= np.nanmin(Z.values)
    Z = Z*1000

    X, Y = np.meshgrid(Z.columns.values, Z.index.values)
    # Plotting the log-likelihood contour
    fig = plt.figure(figsize=[6, 5])
    ax = fig.add_subplot(111)
    plt.title('Contour plot')
    CS = ax.contour(X,Y,Z, 100, cmap='viridis')
    if vals == 'TotalForce':
        label = r'$\Delta$ ' + vals + r' (meV/Å)'
    else:
        label = r'$\Delta$ ' + vals + r' (meV)'
    
    fig.colorbar(CS, ax=ax, label=label)
    # Add x- and y-labels
    ax.set_xlabel(cols[1])
    ax.set_ylabel(cols[0])

    ax.set_xticks(X[0,:], np.round(X[0,:], 3))
    ax.set_yticks(Y[:,0], np.round(Y[:,0], 3))

    #ax.set_xlim(0.1, 0.3)
    # Show the plot using tight layout
    plt.tight_layout()
    plt.show()

# %%
plot_lines(df, xaxis='SplitNorm', yaxis='Enthalpy')

# %%
plot_contour(df, vals='Enthalpy')

# %%
from ase.calculators.siesta.parameters import Species, PAOBasisBlock

# %%
basis_set = PAOBasisBlock(
"""1
0  2 S 0.2
0.0 0.0""")

# %%
basis_set

# %% [markdown]
# <a id="spacegrid"></a>
# ## 2. Real-space grid convergence

# %% [markdown]
# In SIESTA, the real-space grid underpins accuracy and efficiency. Choosing the right cutoff is crucial: too low, and you risk inaccurate results and spurious egg-box effects (variation of the total energy as atoms are displaced with respect to the integration grid); too high, and the calculation becomes unnecessarily expensive.

# %% [markdown]
# In this section, we perform mesh-cutoff convergence

# %%
# This will run the grid convergence script
# Note: This will take a long time to run on local, use cluster
#%run scripts/grid.py

# %%
df = pd.read_csv('results/bulk/BaTiO3/grid/gridconv.csv')
df.tail()

# %%
plot_lines(df, xaxis='MeshCutoff', yaxis='Energy')
plot_lines(df, xaxis='MeshCutoff', yaxis='MaxForce')

# %%
plot_lines(df, xaxis='kgrid', yaxis='Energy')
plot_lines(df, xaxis='kgrid', yaxis='MaxForce')

# %% [markdown]
# <a id="structureopt"></a>
# ## 3. Structural optimization (bulk)

# %% [markdown]
# First we run a relaxation script where we let ASE handle position and cell optimization:

# %%
#relax_ase(BaTiO3, xcf='PBEsol', basis='DZP', cutoff=50, kmesh=[5, 5, 5], mode='pw')

# %%
atoms = read('results/bulk/relax/BaTiO3_pw.xyz')

# %%
atoms.get_cell()

# %%
atoms.get_positions()

# %% [markdown]
# The following function runs a single Siesta calculation which includes relaxation:

# %%
#relax_siesta(BaTiO3, xcf='PBEsol', basis='DZP', cutoff=200, shift=0.008, kmesh=[5, 5, 5])

# %%
atoms = read('results/bulk/relaxsiesta/BaTiO3.xyz')
atoms.get_cell()

# %%
atoms.get_positions()

# %% [markdown]
# <a id="bands"></a>
# ## 4. Band structure and DOS (bulk)

# %% [markdown]
# The band structure can be calculated using either SIESTA or SISL.
# The easiest is to use SISL, which can extract the Hamiltonian and geometry from the generated .HSX file:

# %%
# Read relaxed structures
#BaTiO3_rel = read('bulk/relax/BaTiO3.xyz')
# Calculate band structure and PDOS
# Here commented out to avoid long computation, use cluster
#calculate_bands(BaTiO3, xcf='PBEsol', basis='DZP', cutoff=1200, shift=0.008, kmesh=[10, 10, 10])

# %%
plot_bands('BaTiO3')

# %%
plot_bands_SISL('BaTiO3')

# %%
plot_bands('SrTiO3')

# %%
plot_bands_SISL('SrTiO3')

# %% [markdown]
# <a id="phonons"></a>
# ## 5. Phonon dispersion (bulk)

# %% [markdown]
# We now move on to calculate the phonon dispersion. This is done with Phonopy using SIESTA as the calculator.

# %%
# Read relaxed structures
#BaTiO3 = read('bulk/relax/BaTiO3.xyz')
#SrTiO3 = read('bulk/relax/SrTiO3.xyz')
# Calculate phonon dispersion
# Here commented out to avoid long computation, use cluster
#calculate_phonons(BaTiO3, xcf='PBEsol', basis='DZP', cutoff=1200, shift=0.008, kmesh=[5, 5, 5])

# %%
#phonon.write_animation()

# %%
phonon = ph.load(f'results/bulk/BaTiO3/0064/phonons/BaTiO3.yaml')
#plot_dispersion(phonon)

# %%
from src.frozenphonon import get_modevector

# %%
get_modevector(phonon, [0, 0, 0])

# %%
phonon = ph.load(f'results/bulk/phonons/BaTiO3_pw_PBE.yaml')
plot_dispersion(phonon)

# %%
phonon = ph.load(f'results/bulk/phonons/SrTiO3_phonon.yaml')
plot_dispersion(phonon)

# %% [markdown]
# <a id="mapim"></a>
# ## 6. Mapping imaginary modes

# %%
from scipy.optimize import curve_fit

# %%
dir = 'results/bulk/BaTiO3/0053/frozen'

# %%
df = pd.read_csv(os.path.join(dir, 'G', 'Q_1/energies.csv'))
df.tail()

# %%
def get_time(dir):
    time = np.load(f'{dir}/time.npy')
    # Convert into hours, minutes, seconds in format 00:00:00
    hours = int(time // 3600)
    minutes = int((time % 3600) // 60)
    seconds = int(time % 60)
    print(f'Time taken {hours:02d}:{minutes:02d}:{seconds:02d}')
    return time

# %%
get_time(os.path.join(dir, 'G'))

# %%
# Double well potential

def U_harm(x, omega):
    return -1/2*omega*x**2

def U_anharm(x, a, b):
    return -1/2*a*x**2 + 1/4*b*x**4

def plotDW(dir, mirror=False):
    # Load dataframe
    
    xtickmarks = np.arange(0, 3, 0.5)
    
    colors = {'G': 'tab:blue',
              'X': 'tab:orange',
              'R': 'tab:red',
              'M': 'tab:green'}
    dir_ref = 'results/bulk/BaTiO3/GPAW/frozen'

    # Check for folder names in the directory
    folders = os.listdir(dir)
    N = len(folders)

    # Make N subplots for each q-point, but share y axes
    fig, axes = plt.subplots(1, N, figsize=(3*N, 5), sharey='col')
    plt.subplots_adjust(wspace=0.1)

    # For all q-labels, read the corresponding energies.csv file and extract the total energy and displacement data
    for i, q in enumerate(folders):
        
        def _get_data(df):
            # Extract data for fitting
            xdata = df['Amplitude'].to_numpy()
            ydata = df['Energy'].to_numpy()*1000
            # Set offset to the point where Amplitude is 0
            y0 = df[df['Amplitude'] == 0]['Energy'].iloc[0]*1000
            ydata = (ydata - y0)
            # Find the index of the minimum energy point
            print(f'{q}: Displacement {np.argmin(ydata)} gives a minimum in energy.')
            return xdata, ydata

        def _fit_data(xdata, ydata):
            xfit = np.linspace(0, max(xdata), 1000)

            # Initial fit with harmonic potential on the first 2 points
            #popt_harm, pcov_harm = curve_fit(U_harm, xdata[0:2], ydata[0:2])
            #omega = popt_harm[0]
            #print(f'{q}: Fitted harmonic frequency: {np.sqrt(omega)*0.2418:.3f} THz')

            # Final fit with anharmonic potential on all points
            popt, pcov = curve_fit(U_anharm, xdata, ydata)
            a, b = popt
            print(f'{q}: Fitted harmonic frequency: {np.sqrt(a)*0.2418:.3f} THz')
            dE = a**2/(4*b)
            Q0 = np.sqrt(a*b)/b
            print(f'{q}: dE = {dE:.3f} meV, minimum at Q0 = {Q0:.3f}')
            yfit = U_anharm(xfit, *popt)
            return xfit, yfit

        def _plot_curve(ax, df, val, col):
            
            xdata, ydata = _get_data(df)
            
            xfit, yfit = _fit_data(xdata, ydata)

            if mirror:
                xfit = np.concatenate((-xfit[::-1], xfit))
                yfit = np.concatenate((yfit[::-1], yfit))

            #ax.axhline(y=0, color='k', linestyle=':')


            if q == 'G':
                ax.set_title(f'BaTiO3 - $\Gamma$ point')
            else:
                ax.set_title(f'BaTiO3 - {q} point')
            
            ax.plot(xdata, ydata,'.', color=col, label=val)
            ax.plot(xfit, yfit, '-', lw=1.5, color=col)

            # Plot red point in (0, 0)
            ax.plot(0, 0, 'ro')

            ax.set_xlim(min(xfit), max(xfit))
            ax.set_ylim(-20, 25)

            # Apply custom plot settings to the axes
            PlotSettings().set_style_ax(ax, gridlines=True)
        try:
            Qs = os.listdir(os.path.join(dir_ref, q))
            print(Qs)
            for Q in Qs:
                df_ref = pd.read_csv(os.path.join(dir_ref, q, Q, 'energies.csv'))
                _plot_curve(axes[i], df_ref, val='PW', col='k')
        except:
            print('No GPAW data for this point')
        
        Qs = os.listdir(os.path.join(dir, q))
        for Q in Qs:
            df = pd.read_csv(os.path.join(dir, q, Q, 'energies.csv'))
            _plot_curve(axes[i], df, val='LCAO', col='blue')
        
        # Add legend
        axes[i].legend(loc='upper center')
        # Adding x- and y-labels
        axes[i].set_xlabel(f'$Q_{i+1}$ (amu$^{{1/2}}$Å)')
        # Remove y-tick labels for all but the first and last subplot
        if i != 0:
            axes[i].set_yticklabels([])
    
    axes[0].set_ylabel(r'$\Delta$ Energy (meV/u.c.)')
    # Move y-axis of the last subplot to the right but maintain the y-tickmarks on the left
    axes[-1].tick_params(axis='y', labelright=True, labelleft=False)
    # Show figure
    plt.show()

# %%
plotDW(dir)

# %%
print(f'G:{-3731.468209}')
print(f'X:{-7462.903827/2}')
print(f'M:{-14925.767848/4}')

# %%
dir = 'results/bulk/BaTiO3/GPAW/frozen'

# %%
structures = read(os.path.join(dir, 'M', 'structures.xyz@0:'))  # reads all frames
view(structures)
#write(os.path.join(dir, 'G', f'0.cif'), structures[0])

# %%
# Define formula and ID
formula = 'BaTiO3'
id = '0064'
# Set up directory paths for ID and frozen phonon calculation results
dir_id = os.path.join('results/bulk/',formula, id)
dir_res = os.path.join(dir_id, 'frozen')

def unpack_params(dir):
    # Load parameters.json file for this formula and ID from the directory
    params = pd.read_json(os.path.join(dir, 'parameters.json'), orient='index').to_dict()[0]
    # Convert EnergyShift, SplitNorm and MeshCutoff to float
    params['EnergyShift'] = float(params['EnergyShift'])
    params['SplitNorm'] = float(params['SplitNorm'])
    params['MeshCutoff'] = float(params['MeshCutoff'])
    # Convert kgrid to tuple
    params['kgrid'] = tuple(map(int, params['kgrid'].strip('()').split(',')))
    return params
params = unpack_params(dir_id)
params

# %%
atoms = read(os.path.join(dir, 'M', f'{formula}.xyz'), index=0)
atoms.cell
write(os.path.join(dir, 'M', f'{formula}.cif'), atoms)

# %%
view(atoms)

# %% [markdown]
# <a id="bandsslab"></a>
# ## 7. Band structures and phonons in slabs

# %%
perovskite = Perovskite('BaTiO3', a=3.98, N=1, bulk=False)
view(perovskite.atoms)

# %%
relax_ase(perovskite, xcf='PBEsol', basis='DZP', EnergyShift=0.01, SplitNorm=0.15,
          MeshCutoff=200, kgrid=(10, 10, 1), pseudo='PBEsol', dir='resultsold/slab/relax')

# %%
view(read('resultsold/slab/relax/BaTiO3.xyz'))

# %%
perovskite = Perovskite('SrTiO3', N=1, bulk=False)
view(perovskite.atoms)

# %%
formula = 'BaTiO3'
perovskite = Perovskite(formula, a=3.98, N=1, bulk=False)
project = SiestaProject(perovskite)
project.path

# %%
from src.phononcalc import get_phonon_pdos, order_labels

# %%
phonon = ph.load(f'results/slab/BaTiO3/1uc/0001/phonons/BaTiO3.yaml')

# %%
def _plot_pdos(ax, phonon):
    atom_colors = {'Ba': 'tab:blue', 'Sr': 'tab:purple',
                    'Ti': 'tab:orange', 'O': 'tab:red'}
    # Extract PDOS data
    (pdosx, pdosy, symbols) = get_phonon_pdos(phonon, bulk=False)
    print(len(symbols))
    # Plot PDOS
    for i in range(pdosx.shape[0]):
        ax.plot(pdosx[i], pdosy, lw=1.5, color=atom_colors[symbols[i]], label=f'{symbols[i]}')
    # Get all handles and labels
    handles, labels = ax.get_legend_handles_labels()
    # Remove duplicates and sort for the legend
    sorted_handles, sorted_labels = order_labels(symbols, handles, labels)
    # Add legend with duplicates removed and sorted labels
    ax.legend(sorted_handles, sorted_labels, loc='best', fontsize=14)

# %%
fig, ax = plt.subplots(figsize=[6, 5])
_plot_pdos(ax, phonon)

# %% [markdown]
# ## Tests

# %%
formula = 'BaTiO3'
perovskite = Perovskite(formula, a=3.98, bulk=True)
project = SiestaProject(perovskite)
df = project.get_summary()
df.tail()

# %%
def filter_df(df, reference_id, param):
    # First cast all NaN values to 1
    df = df.fillna('1')
    # Find the row corresponding to the reference ID
    reference = df[df['ID'] == reference_id].iloc[0]
    # Find the columns to match (all columns except 'ID' and the parameter of interest)
    cols_to_match = df.columns.difference(['ID', param, 'relax', 'phonons', 'kgrid'])
    mask = (df[cols_to_match] == reference[cols_to_match]).all(axis=1)
    return df[mask].sort_values(by=param)

rdf = filter_df(df, '0073', 'basis')
#rdf = rdf[rdf['ID'].isin(['0053', '0062', '0065'])]
ids = np.array(rdf['ID'])
vals = np.array(rdf['basis'])
rdf

# %%
from src.bandscalc import plot_bands2
from src.phononcalc import plot_dispersion2

# %%
phonon = ph.load(os.path.join('results/bulk/SrTiO3/0035/phonons/SrTiO3.yaml'))

# %%
plot_dispersion(phonon, pDOS=False)

# %%
dir = os.path.join('results/bulk/','BaTiO3', '0053', 'bands')
sile_PDOS = si.get_sile(os.path.join(dir, f"BaTiO3.PDOS"))
geom, E, PDOS = sile_PDOS.read_data()
PDOS = np.squeeze(PDOS)
orbits = geom.atoms.orbitals
DOS = PDOS.sum(axis=0)

# %%
idx = np.cumsum(np.r_[0, orbits[:-1]])
PDOS_atom = np.add.reduceat(PDOS, idx, axis=0)

# %%
atom_colors = {'Ba': 'tab:blue', 'Sr': 'tab:purple',
               'Ti': 'tab:orange', 'O': 'tab:red'}

# %%
for i in range(PDOS_atom.shape[0]):
    symbol = geom.atoms[i].symbol
    plt.plot(E, PDOS_atom[i], color=atom_colors[symbol], label=f'{symbol}')
plt.xlabel('Energy (eV)')
plt.ylabel('PDOS (states/eV)')
plt.xlim(-6, 6)
plt.title('Projected Density of States for BaTiO3')
plt.legend()
plt.show()

# %%
plot_bands('BaTiO3', ids=ids, vals=['LCAO (st.)', 'LCAO (opt.)'])
plot_bands2('BaTiO3', ids=ids, vals=['LCAO (st.)', 'LCAO (opt.)'])
#plot_DOS('BaTiO3', ids=ids, vals=['LCAO'])

# %%
plot_dispersion('BaTiO3', ids=ids, vals=['LCAO (st.)', 'LCAO (opt.)'])
plot_dispersion2('BaTiO3', ids=ids, vals=['LCAO (st.)', 'LCAO (opt.)'])

# %%
rdf = filter_df(df, '0027', 'SplitNorm')
ids = np.array(rdf['ID'])
vals = np.array(rdf['SplitNorm'])
rdf

# %%
plot_bands2('SrTiO3', ids=ids, vals=vals)

# %%
plot_dispersion2('SrTiO3', ids=ids, vals=vals)

# %%
rdf = filter_df(df, '0004', 'EnergyShift')
ids = np.array(rdf['ID'])
vals = np.array(rdf['EnergyShift'])
rdf

# %%
from src.phononcalc import get_phonon_dispersion
def get_lattice(formula, dir):
    atoms = read(f'{dir}/{formula}.xyz')
    cell = atoms.get_cell()
    return cell

def get_phonon_frequencies(formula, dir):
    phonon = ph.load(f'{dir}/{formula}.yaml')
    # Extract phonon dispersion data
    (dist, X, freq, labels) = get_phonon_dispersion(phonon, bulk=True)
    n_segments = len(freq)
    n_modes = freq[0].shape[1]

    fmode = [np.min(freq[0][0, :])]

    for i in range(n_segments):
        fmode.append(np.min(freq[i][-1, :]))
    # Return dictionary with labels and frequencies
    return dict(zip(labels, fmode))

# %%
def plot_lattice(formula, reference_id, param):
    project = SiestaProject(material=formula, bulk=False)
    dir = project.path
    print(dir)
    df = project.get_summary()
    rdf = filter_df(df, reference_id, param)
    ids = np.array(rdf['ID'])
    if param == 'EnergyShift' or param == 'MeshCutoff':
        rdf[param] = rdf[param].str.replace(' Ry', '').astype(float)
    vals = np.array(rdf[param])
    lats = []
    cell_pw = get_lattice(formula, f'results/slab/{formula}/1uc/GPAW/relax')
    for calc_id in ids:
        cell = get_lattice(formula, os.path.join(dir, calc_id, 'relax'))
        a = cell[0, 0] - cell_pw[0, 0]
        b = cell[1, 1] - cell_pw[1, 1]
        c = cell[2, 2] - cell_pw[2, 2]
        lats.append((a, b, c))
    a_values = [lat[0] for lat in lats]
    b_values = [lat[1] for lat in lats]
    c_values = [lat[2] for lat in lats]

    fig = plt.figure()
    ax = fig.add_subplot(111)
    # Plot lattice constants vs parameter values
    ax.plot(vals, a_values, marker='o', label='a (Å)')
    ax.plot(vals, b_values, marker='o', label='b (Å)')
    ax.plot(vals, c_values, marker='o', label='c (Å)')
    # Add legend
    ax.legend()
    # Add x- and y-labels
    ax.set_xlabel(param)
    ax.set_ylabel(r'$\Delta$ Lattice constant (Å)')
    # Apply custom plot settings to the axes
    PlotSettings().set_style_ax(ax, gridlines=True)
    # Show the plot using tight layout
    plt.tight_layout()
    plt.show()

# %%
def plot_phononfreq(formula, reference_id, param):
    project = SiestaProject(material=formula)
    dir = project.path
    df = project.get_summary()
    rdf = filter_df(df, reference_id, param)
    ids = np.array(rdf['ID'])
    vals = np.array(rdf[param])
    freq = []
    for calc_id in ids:
        frequens = get_phonon_frequencies(formula, os.path.join(dir, calc_id, 'phonons'))
        G = frequens['$\\Gamma$']
        X = frequens['X']
        R = frequens['R']
        M = frequens['M']
        freq.append((G, X, R, M))

    Gvals = [f[0] for f in freq]
    Xvals = [f[1] for f in freq]
    Rvals = [f[2] for f in freq]
    Mvals = [f[3] for f in freq]

    fig = plt.figure()
    ax = fig.add_subplot(111)
    # Plot phonon frequencies vs parameter values
    ax.plot(vals, Gvals, marker='o', label='$\\Gamma$')
    ax.plot(vals, Xvals, marker='o', label='X')
    ax.plot(vals, Rvals, marker='o', label='R')
    ax.plot(vals, Mvals, marker='o', label='M')
    # Add legend
    ax.legend()
    # Add x- and y-labels
    ax.set_xlabel(param)
    ax.set_ylabel('Phonon Frequency (THz)')
    # Apply custom plot settings to the axes
    PlotSettings().set_style_ax(ax, gridlines=True)
    # Show the plot using tight layout
    plt.tight_layout()
    plt.show()

# %%
rdf = filter_df(df, '0025', 'EnergyShift')
ids = np.array(rdf['ID'])
vals = np.array(rdf['EnergyShift'])
rdf

# %%
plot_lattice('BaTiO3', '0001', 'EnergyShift')
plot_phononfreq('BaTiO3', '0001', 'EnergyShift')

# %%
formula = 'BaTiO3'
id = '0064'
qp = 'R'

# Set the results directory
dir_res = os.path.join('results/bulk/',formula,'frozen')
dir_id = os.path.join('results/bulk/',formula, id)

# Load .xyz and .yaml file from relaxation and phonon calculation
atoms = read(os.path.join(dir_id, f'relax/{formula}.xyz'))
phonon = ph.load(os.path.join(dir_id, f'phonons/{formula}.yaml'))

# Dictionary for q-points
q_dict = {
    'G': [0.0, 0.0, 0.0],
    'X': [0.5, 0.0, 0.0],
    'R': [0.5, 0.5, 0.5],
    'M': [0.5, 0.5, 0.0],
}

q = q_dict[qp]

# %%
modevec, stable = get_modevector(phonon, q)

# %%
supercell = displace_atoms(atoms, q, modevec, 0.1)

# %%
len(supercell)

# %%
# Make a small animation of the displacement of the atoms along the mode vector for the given q-point
from ase.visualize import view
from ase.io import write

if not stable:
    # Animate
    n_steps = 100 # number of steps in the animation
    A = 5.0 # amplitude of the displacement
    images = []
    for i in range(n_steps):
        phase = 2 * np.pi * i / n_steps # phase in time
        dis = A*np.cos(phase)
        supercell = displace_atoms(atoms, qp, modevec, dis)
        images.append(supercell)
    # Save as .xyz animation
    write(f'resultsold/bulk/anim/{formula}_{qp}.xyz', images)

# %%
animation = read(f'resultsold/bulk/anim/{formula}_{qp}.xyz@0:')  # reads all frames
view(animation)

# %%
view(displace_atoms(atoms, modevec, qp, 0.5))

# %%
view(atoms)

# %%
phonon.unitcell.symbols

# %%
def get_time(dir):
    time = np.load(f'{dir}/time.npy')
    # Convert into hours, minutes, seconds in format 00:00:00
    hours = int(time // 3600)
    minutes = int((time % 3600) // 60)
    seconds = int(time % 60)
    print(f'Time taken {hours:02d}:{minutes:02d}:{seconds:02d}')
    return time

get_time(os.path.join(dir_res, 'G'))

# %%
from phonopy.phonon.band_structure import get_band_qpoints_and_path_connections
import phonopy as ph
phonon = ph.load('results/bulk/BaTiO3/GPAW/phonons/BaTiO3.yaml')

# %%
def run_all_phonon(dir, bulk=True):

    phonon = ph.load(os.path.join(dir, 'BaTiO3.yaml'))

    if bulk:
        path = [[[0.0, 0.0, 0.0],[0.5, 0.0, 0.0],[0.5, 0.5, 0.5],
                 [0.5, 0.5, 0.0],[0.0, 0.0, 0.0],[0.5, 0.5, 0.5]]]
        labels = ["$\\Gamma$", "X", "R", "M", "$\\Gamma$", "R"]
    else:
        path = [[[0.0, 0.0, 0.0],[0.5, 0.0, 0.0],
                 [0.5, 0.5, 0.0],[0.0, 0.0, 0.0]]]
        labels = ["$\\Gamma$", "X", "M", "$\\Gamma$"]

    qpoints, connections = get_band_qpoints_and_path_connections(path, npoints=50)

    # --- Band structure ---
    phonon.run_band_structure(
        qpoints,
        path_connections=connections,
        labels=labels,
        with_eigenvectors=True
    )

    phonon.write_yaml_band_structure(filename=os.path.join(dir, "band.yaml"))

# %%
run_all_phonon('results/bulk/BaTiO3/GPAW/phonons', bulk=True)

# %%
from src.frozenphonon import phonon_to_atoms, get_modevector, get_displacement

# %%
phonon = ph.load('results/bulk/BaTiO3/GPAW/phonons/BaTiO3.yaml')
unitcell = phonon_to_atoms(phonon, cell='unit')

# %%
from src.frozenphonon import calculate_frozen_phonons

# %%
calculate_frozen_phonons(phonon, dd=0.1, xcf='PBEsol', basis='DZP',
                        EnergyShift=0.01, SplitNorm=0.15,
                        MeshCutoff=100, kgrid=(4, 4, 4),
                        pseudo='PBEsol', mode='lcao',
                        dir='resultsold/frozentest', par=False)

# %%
# Load the energies from the frozen phonon calculation
df = pd.read_csv('resultsold/frozentest/G/Q_1/energies.csv')
df

# %%
# Plot
for i in range(3):
    df = pd.read_csv(f'resultsold/frozentest/G/Q_{i}/energies.csv')

    plt.plot(df['Amplitude'], (df['Energy']-df['Energy'][0])*1000, marker='o')
plt.xlabel('Displacement amplitude (amu$^{1/2}$Å)')
plt.ylabel('Energy (meV)')
plt.title('Frozen phonon calculation for BaTiO3 at G point')
plt.grid()
plt.show()

# %%
qpoint = 'M'

# %%
# Dictionary for q-points
q_dict = {
    'G': [0.0, 0.0, 0.0],
    'X': [0.5, 0.0, 0.0],
    'R': [0.5, 0.5, 0.5],
    'M': [0.5, 0.5, 0.0],
}
q = q_dict[qpoint]
# Get mode vector and stability of the mode at the given q-point
modevec, stable = get_modevector(phonon, q)
print(modevec)

## If the mode is stable, skip the frozen phonon calculations for this q-point
"""
# Generate the supercell and get the mode vector for the supercell
modevec_sc, supercell, supercell_matrix = get_displacement(unitcell, q, modevec)
#print(modevec_sc)

# Determine the supercell size in each direction from the diagonal of the supercell matrix
nx, ny, nz = supercell_matrix.diagonal().astype(int)
ncells = nx*ny*nz

amp = 0.5
amplitudes = []
energies = []
images = []
for phase in np.linspace(-20, 20, 41):
    # Create a copy of the supercell
    supercell_disp = supercell.copy()
    # Displace the atoms according to the mode vector and the current amplitude
    supercell_disp.positions += amp * np.real(np.exp(1j * phase) * modevec_sc)
    # Append images
    images.append(supercell_disp)
"""
# Save the animations of the displacements for this q-point
#write(f'testanim.xyz', images)

# %% [markdown]
# [[-4.75367312e-16+0.00000000e+00j -2.60215461e-16+9.96790523e-17j
#    3.00505675e-16+1.08984613e-17j]
#  [ 1.11022302e-16+3.98545576e-18j  9.68141699e-17-2.23359988e-24j
#   -9.15145143e-01+2.15548238e-08j]
#  [-8.32667268e-17-3.63517786e-18j -5.55111512e-17-8.17135639e-31j
#    3.25090979e-17-5.55111512e-17j]
#  [ 8.32667268e-17+6.77468214e-32j  1.56125113e-17+6.35774276e-19j
#    3.04803071e-17-6.74007457e-20j]
#  [ 5.98479599e-17+3.81602007e-18j  4.17338742e-17-9.62842255e-25j
#    4.03124506e-01-9.49497222e-09j]]

# %%
view(read('testanim.xyz@0:'))

# %% [markdown]
# [[-1.16677929e-03+0.00000000e+00j -3.48611675e-01+1.36208106e-03j
#    9.30265619e-01+1.13321539e-01j]
#  [-1.06475860e-16-5.39020171e-17j  8.73097504e-17-6.92641632e-17j
#   -1.02540294e-17+1.84256643e-16j]
#  [-9.99426077e-03-1.21746419e-03j  8.32667268e-17-4.44089210e-16j
#    1.25352332e-05+9.07557449e-14j]
#  [-2.11650995e-16+4.41853675e-16j -9.99426077e-03-1.21746419e-03j
#    3.74529158e-03-1.46334206e-05j]
#  [ 3.74529158e-03-1.46334206e-05j  1.25352332e-05+9.06728035e-14j
#    1.38777878e-16+0.00000000e+00j]]

# %%
np.linalg.norm(modevec)

# %%
# View the animation
#view(read('BTO_PW_X.xyz@0:'))
#view(read('BTO_LCAO_X.xyz@0:'))
