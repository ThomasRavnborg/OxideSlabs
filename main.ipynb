# %% [markdown]
# # Main

# %%
# Importing libraries
import os
import numpy as np
import pandas as pd
import sisl as si
import matplotlib.pyplot as plt
# ASE modules
from ase import Atoms
from ase.calculators.siesta import Siesta
from ase.units import Ry
from ase.visualize import view
from ase.io import read, write
# Path module
from pathlib import Path
# Matplotlib ticker
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
# Custom modules
#from codes.bulkBS import calcBS, calcPDOS
from codes.bandstructure import calculate_bands
from codes.bulkPH import calcPhonons
from codes.cleanfiles import cleanFiles
from codes.parameterconv import calcSiesta
from codes.structureoptimizer import perovskite, relaxASE, relaxSiesta
from codes.plotsettings import PlotSettings
PlotSettings().set_global_style()

# %% [markdown]
# ## Contents
# This notebook contains the following sections:
# 1. [Basis set optimization](#basisset)
# 2. [Real-space grid optimization](#spacegrid)
# 3. [Structural optimization (bulk)](#structureopt)
# 4. [Band structure and DOS (bulk)](#bands)
# 5. [Phonon dispersion (bulk)](#phonons)

# %% [markdown]
# <a id="basisset"></a>
# ## 1. Basis set optimization

# %% [markdown]
# Although the default basis sets generated by SIESTA might be enough for some applications, we start by doing some optimization of the basis sets, which can help achieve better results with similar computational costs.

# %% [markdown]
# SIESTA uses atomic-centered basis sets (LCAO) on the form:
# \begin{equation*}
# \psi=R(r)Y_{ml}(\theta,\phi)
# \end{equation*}

# %%
from codes.parameterconv import calcSiesta

# %%
BaTiO3 = perovskite('BaTiO3')

# %%
BaTiO3 = perovskite('BaTiO3')
# Move one of the atoms to create a force
BaTiO3[0].position += [0.1, 0.0, 0.0]
view(BaTiO3)
# Out:
# <Popen: returncode: None args: ['/home/tbrav/miniconda3/envs/siesta-env/bin/...>

# %%
calcSiesta(BaTiO3, cutoff=100, shift=0.01, split=0.15)
# Out:
# Job completed

# %%
si.io.siesta.structSileSiesta('bulk/basis/BaTiO3.STRUCT_OUT').read_geometry()
# Out:
# <sisl.Geometry na=5, no=5, nsc=[1 1 1]>

# %%
si.io.siesta.xvSileSiesta('bulk/basis/BaTiO3.XV').read_geometry()
# Out:
# <sisl.Geometry na=5, no=5, nsc=[1 1 1]>

# %%
sile = si.io.siesta.stdoutSileSiesta('bulk/basis/BaTiO3.out')
sile.read_energy()
# Out:
# warn:0: SislWarning: Could not convert energy 'basis.enthalpy' (       -2221.002147 eV
# ) to a float, assigning nan.
# {'band': -501.680931,
#  'kinetic': 1219.076931,
#  'hartree': 400.626281,
#  'dftu': 0.0,
#  'spin_orbit': 0.0,
#  'extE': 0.0,
#  'exchange': -530.938376,
#  'correlation': -43.316268,
#  'bulkV': 0.0,
#  'xc': -574.254643,
#  'ion': {'electron': -1945.554763, 'ion': -1324.168131, 'kinetic': 0.0},
#  'D3 dispersion': 0.0,
#  'total': -2224.274325,
#  'fermi': -7.10699,
#  'basis': {'enthalpy': nan}}

# %%
with open('bulk/basis/BaTiO3.BASIS_ENTHALPY', 'r') as file:
    lines = file.readlines()
basis_enthalpy = float(lines[0].split()[-1])
total_energy = float(lines[3].split()[-1])
print("Basis enthalpy (eV):", basis_enthalpy)
# Out:
# Basis enthalpy (eV): -2221.0021465191253

# %%
df = pd.read_csv('bulk/basis/basisopt.csv', index_col=0)
df.head()
# Out:
#    Shift  Split     Enthalpy  MaxForce
# 0  0.001   0.01 -2217.987899  0.431084
# 1  0.001   0.05 -2219.463347  0.449341
# 2  0.001   0.10 -2219.991294  0.378782
# 3  0.001   0.15 -2220.082546  0.365684
# 4  0.001   0.20 -2220.064524  0.369930

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(7, 5))

for shift, data in df.groupby('Shift'):
    ax.plot(data['Split'], data['Enthalpy'], marker='o', label=f'Shift = {shift} Ry')

ax.set_xlabel('SplitNorm')
ax.set_ylabel('Basis Set Enthalpy (eV)')
#ax.set_title('Basis Set Enthalpy vs SplitNorm for Different Energy Shift Values')
ax.legend()
ax.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# %%
Z = df.pivot(index="Shift", columns="Split", values="Enthalpy")
X, Y = np.meshgrid(Z.columns.values, Z.index.values)
# Plotting the log-likelihood contour
fig = plt.figure(figsize=[6, 5])
ax = fig.add_subplot(111)
plt.title('Contour plot')
CS = ax.contour(X,Y,Z, 100, cmap='viridis')
fig.colorbar(CS, ax=ax)
# Add x- and y-labels
ax.set_xlabel('SplitNorm')
ax.set_ylabel('EnergyShift (Ry)')
# Set logarithmic scale for y-axis
ax.set_yscale('log')
# Show the plot using tight layout
plt.tight_layout()
plt.show()

# %%
from ase.calculators.siesta.parameters import Species, PAOBasisBlock

# %%
basis_set = PAOBasisBlock(
"""1
0  2 S 0.2
0.0 0.0""")

# %%
basis_set
# Out:
# {'block': '1\n    0  2 S 0.2\n    0.0 0.0'}

# %% [markdown]
# <a id="spacegrid"></a>
# ## 2. Real-space grid convergence

# %% [markdown]
# In SIESTA, the real-space grid underpins accuracy and efficiency. Choosing the right cutoff is crucial: too low, and you risk inaccurate results and spurious egg-box effects (variation of the total energy as atoms are displaced with respect to the integration grid); too high, and the calculation becomes unnecessarily expensive.

# %% [markdown]
# In this section, we perform mesh-cutoff convergence

# %%
df = pd.read_csv('bulk/grid/gridopt.csv', index_col=0)
#df = df[df["MeshCutoff"]>=100]
df.head()
# Out:
#    MeshCutoff  KPoints     Enthalpy  MaxForce
# 0         100        5 -2222.047309  0.347548
# 1         100       10 -2222.055626  0.349204
# 2         100       15 -2222.055728  0.349292
# 3         100       20 -2222.055731  0.349309
# 4         200        5 -2221.936557  0.348383

# %%
fig, ax = plt.subplots(figsize=(7, 5))

for k, data in df.groupby('KPoints'):
    ax.plot(data['MeshCutoff'], data['Enthalpy'], marker='o', label=f'KPoints = {k}x{k}x{k}')

ax.set_xlabel('Mesh Cutoff (Ry)')
ax.set_ylabel('Basis Set Enthalpy (eV)')
#ax.set_title('Basis Set Enthalpy vs SplitNorm for Different Energy Shift Values')
ax.legend()
ax.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(7, 5))

for k, data in df.groupby('KPoints'):
    ax.plot(data['MeshCutoff'], data['MaxForce'], marker='o', label=f'KPoints = {k}x{k}x{k}')

ax.set_xlabel('Mesh Cutoff (Ry)')
ax.set_ylabel('Max Force (eV/Å)')
#ax.set_title('Basis Set Enthalpy vs SplitNorm for Different Energy Shift Values')
ax.legend()
ax.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# %% [markdown]
# <a id="structureopt"></a>
# ## 3. Structural optimization (bulk)

# %% [markdown]
# First we run a relaxation script where we let ASE handle position and cell optimization:

# %%
BaTiO3 = perovskite('BaTiO3')

# %%
relaxASE(BaTiO3, xcf='PBEsol', basis='DZP', cutoff=800, shift=0.008,
         kmesh=[10, 10, 10], fmax=0.005, filt=True)
# Out:
# Job completed
# Job completed
# Job completed

# %%
from ase.io.trajectory import Trajectory
traj = Trajectory('bulk/relax/relax.traj')

# %%
cleanFiles('bulk/relax', formats=['.traj'])
# Out:
# All files in bulk/relax except the following will be deleted:
# BaTiO3.xyz
# BaTiO3.fdf
# relax.traj
# BaTiO3.out
# BaTiO3.XV
# BaTiO3_PBE.xyz
# BaTiO3.DM
# BaTiO3.HSX
# Files successfully deleted.
# Files successfully deleted.
# Files successfully deleted.
# Files successfully deleted.
# Files successfully deleted.
# Files successfully deleted.
# Files successfully deleted.
# Files successfully deleted.
# Files successfully deleted.
# Files successfully deleted.
# Files successfully deleted.
# Files successfully deleted.
# Files successfully deleted.
# Files successfully deleted.
# Files successfully deleted.
# Files successfully deleted.
# Files successfully deleted.
# Files successfully deleted.
# Files successfully deleted.
# Files successfully deleted.
# Files successfully deleted.
# Files successfully deleted.
# Files successfully deleted.
# Files successfully deleted.
# Files successfully deleted.
# Files successfully deleted.
# Files successfully deleted.
# ...

# %%
atoms = read('bulk/relax/BaTiO3.xyz')

# %%
atoms.get_cell()
# Out:
# Cell([[4.019612628545467, 0.0, 0.0], [-2.182621886239049e-19, 4.019612628545467, 0.0], [0.0, 0.0, 4.019612628545467]])

# %%
atoms.get_positions()
# Out:
# array([[ 0.        ,  0.        ,  0.        ],
#        [ 2.00980631,  2.00980631,  2.00980631],
#        [ 2.00980631,  0.        ,  2.00980631],
#        [-0.        ,  2.00980631,  2.00980631],
#        [ 2.00980631,  2.00980631,  0.        ]])

# %% [markdown]
# The following function runs a single Siesta calculation which includes relaxation:

# %%
relaxSiesta(BaTiO3, xcf='PBEsol', basis='DZP', cutoff=800, shift=0.008,
            kmesh=[10, 10, 10], fmax=0.005, smax=0.01)
# Out:
# Job completed

# %%
cleanFiles('bulk/relaxsiesta')
# Out:
# All files in bulk/relaxsiesta except the following will be deleted:
# BaTiO3.fdf
# BaTiO3.out
# BaTiO3.DM
# BaTiO3.XV
# BaTiO3.xyz
# BaTiO3.HSX
# Files successfully deleted.

# %%
atoms = read('bulk/relaxsiesta/BaTiO3.xyz')
atoms.get_cell()
# Out:
# Cell([[4.01921105446119, -0.0, 0.0], [-0.0, 4.019211327516631, 5.29177210903e-10], [0.0, 5.29177210903e-10, 4.019210282920817]])

# %%
atoms.get_positions()
# Out:
# array([[-0.00000000e+00,  0.00000000e+00, -4.00000000e-08],
#        [ 2.00960553e+00,  2.00960566e+00,  2.00960527e+00],
#        [ 2.00960553e+00,  0.00000000e+00,  2.00960516e+00],
#        [-0.00000000e+00,  2.00960566e+00,  2.00960522e+00],
#        [ 2.00960553e+00,  2.00960566e+00,  5.00000000e-07]])

# %% [markdown]
# <a id="bands"></a>
# ## 4. Band structure and DOS (bulk)

# %% [markdown]
# The band structure can be calculated using either SIESTA or SISL.
# The easiest is to use SISL, which can extract the Hamiltonian and geometry from the generated .HSX file:

# %%
sile = si.get_sile('bulk/relaxsiesta/BaTiO3.HSX')
H = sile.read_hamiltonian()
geom = sile.read_geometry()
Ef = sile.read_fermi_level()

# %% [markdown]
# From the Hamiltonian and geometry, the Band structure can easily be calculated:

# %%
print("Fermi level (eV):", Ef)
# Calculate band-structure using SISL
band = si.BandStructure(geom, [[0.0, 0.0, 0.0],     # Gamma
                               [0.5, 0.0, 0.0],     # X
                               [0.5, 0.5, 0.5],     # R
                               [0.5, 0.5, 0.0],     # M
                               [0.0, 0.0, 0.0],     # Gamma
                               [0.5, 0.5, 0.5]],    # R
                               301,                 # number of k-points
                               [r'$\Gamma$','X', 'R', 'M', r'$\Gamma$', 'R'])
xtick, xtick_label = band.lineartick()
lk = band.lineark()
fig = plt.figure(figsize=[6.6, 5])
ax = plt.gca()
ax.xaxis.set_ticks(xtick)
ax.set_xticklabels(xtick_label)

# Plot vertical lines at symmetry points
ax.vlines(xtick, -6, 6, color='0.5', linewidth=1)
# Plot dashed line at Fermi level
ax.axhline(y=0, color='k', linestyle=':')

# Plot band-structures
band.set_parent(H)
eigs = band.apply.ndarray.eigh()
ax.plot(lk, eigs, color='k')

# Set x- and y-label
ax.set_xlabel('k-points')
ax.set_ylabel('Energy, $E-E_F$ (eV)')
# Set x- and y-limits
ax.set_xlim(xtick[0], xtick[-1])
ax.set_ylim(-6, 6)
# Add minor tickmarks to the y-axis
#ax.yaxis.set_minor_locator(AutoMinorLocator())
#PlotSettings().set_style_ax(ax, minimalist=True)
# Show the plot using tight layout
plt.tight_layout()
plt.show()
# Out:
# Fermi level (eV): -7.296665111759066

# %% [markdown]
# The DOS and PDOS can also be calculated with both SIESTA and SISL.

# %% [markdown]
# First we try with SIESTA by adding arguments to the .fdf file

# %%
BaTiO3_rel = read('bulk/relax/BaTiO3.xyz')

# %%
calculate_bands(BaTiO3_rel, xcf='PBEsol', basis='DZP', cutoff=800, shift=0.008, kmesh=[10,10,10])
# Out:
# Job completed

# %%
def getPDOS(formula):
    sile = si.get_sile(f'bulk/bandstructure/{formula}.PDOS')
    geom, E, data = sile.read_data()
    data = np.squeeze(data)
    DOS = data.sum(axis=0)
    nos = geom.orbitals
    splits = np.cumsum(nos)[:-1]
    PDOS = np.vstack([chunk.sum(axis=0) for chunk in np.split(data, splits, axis=0)])
    return E, DOS, PDOS

# %%
# Plot DOS and PDOS
fig, ax = plt.subplots(figsize=[6.6, 5])

E, DOS, PDOS = getPDOS('BaTiO3')

ax.plot(E, DOS, 'k', label="DOS")
ax.plot(E, PDOS[0, :], color='tab:blue', label=f'PDOS Atom A')
ax.plot(E, PDOS[1, :], color='tab:orange', label=f'PDOS Atom B')
for i in np.arange(2, 5):
    if i ==2:
        ax.plot(E, PDOS[i, :], color='tab:red', label=f'PDOS Atom X')
    else:
        ax.plot(E, PDOS[i, :], color='tab:red')
ax.legend()

# Set x- and y-label
ax.set_xlabel('Energy, $E-E_F$ (eV)')
ax.set_ylabel('Density of States (1/eV)')
# Set x- and y-limits
#ax.set_xlim(X[0][0], X[0][-1])
#ax.set_xlim(-6, 6)
# Add minor tickmarks to the y-axis
ax.yaxis.set_minor_locator(AutoMinorLocator())
# Show the plot using tight layout
plt.tight_layout()
plt.show()

# %% [markdown]
# Now, we can plot them together:

# %%
# Define a function that plots the bandstructure and DOS together
def plotBandstructure(formula):
    """Function to plot bandstructure and DOS for a given formula.
    Parameters:
    - formula: Chemical formula of the material.
    """
    sile_HSX = si.get_sile(f'bulk/bandstructure/{formula}.HSX')
    H = sile_HSX.read_hamiltonian()
    geom = sile_HSX.read_geometry()
    Ef = sile_HSX.read_fermi_level()
    print("Fermi level (eV):", Ef)
    
    # Define tickmarks for the x- and y-axis
    ytickmarks = np.arange(-6, 8, 2)
    xtickmarks = np.arange(0, 7, 1)
    
    # Make a simple figure where graphs are plotted
    fig = plt.figure(figsize=[6.6, 5])

    # Subplot 1 - Band structure
    ax1 = fig.add_axes([0, 0, 1, 1])
    # Calculate band-structure using SISL
    band = si.BandStructure(geom, [ [0.0, 0.0, 0.0],     # Gamma
                                    [0.5, 0.0, 0.0],     # X
                                    [0.5, 0.5, 0.5],     # R
                                    [0.5, 0.5, 0.0],     # M
                                    [0.0, 0.0, 0.0],     # Gamma
                                    [0.5, 0.5, 0.5]      # R
                                    ], 301,              # number of k-points
                                    [r'$\Gamma$','X', 'R', 'M', r'$\Gamma$', 'R'])
    xtick, xtick_label = band.lineartick()
    lk = band.lineark()
    ax1.xaxis.set_ticks(xtick)
    ax1.set_xticklabels(xtick_label)

    # Plot vertical lines at symmetry points
    ax1.vlines(xtick, ytickmarks[0], ytickmarks[-1], color='0.5', linewidth=1)
    # Plot dashed line at Fermi level
    ax1.axhline(y=0, color='k', linestyle=':')

    # Plot band-structures
    band.set_parent(H)
    eigs = band.apply.ndarray.eigh()
    ax1.plot(lk, eigs, color='k')

    # Set x- and y-label
    ax1.set_xlabel('k-points')
    ax1.set_ylabel('Energy, $E-E_F$ (eV)')
    # Set x- and y-limits
    ax1.set_xlim(xtick[0], xtick[-1])
    ax1.set_ylim(ytickmarks[0], ytickmarks[-1])
    # Add minor tickmarks to the y-axis
    ax1.yaxis.set_minor_locator(AutoMinorLocator())
    
    # Subplot 2 - Density of states (DOS)

    sile_PDOS = si.get_sile(f'bulk/bandstructure/{formula}.PDOS')
    geom, E, PDOS = sile_PDOS.read_data()
    PDOS = np.squeeze(PDOS)
    ax2 = fig.add_axes([1.05, 0, 0.4, 1])
    # Add title
    #ax2.set_title('Density of states')
    # Plot dashed line at Fermi level
    ax2.axhline(y=0, color='k', linestyle=':')
    # Plot total density of states

    ax2.plot(PDOS.sum(axis=0), E, 'k', label="DOS")
    # Customize y-axis label and other parameters if needed
    ax2.set_xlabel('DOS (1/eV)')
    # Force x- and y-ticks
    ax2.set_xticks(xtickmarks, xtickmarks)
    ax2.set_yticks(ytickmarks, ytickmarks)
    # Set limits to match
    ax2.set_xlim(xtickmarks[0], xtickmarks[-1])
    ax2.set_ylim(ytickmarks[0], ytickmarks[-1])
    # Hide y-tick labels
    ax2.set_yticklabels([])
    # Show figure
    plt.show()

# %%
plotBandstructure('BaTiO3')
# Out:
# Fermi level (eV): -7.29425339004041

# %% [markdown]
# Now we try with SISL

# %%
sile_HSX = si.get_sile('bulk/relaxsiesta/BaTiO3.HSX')
H = sile_HSX.read_hamiltonian()
geom = sile_HSX.read_geometry()
Ef = sile_HSX.read_fermi_level()

# %%
E = np.linspace(-6, 6, 500)

# %%
mp = si.MonkhorstPack(H, [10, 10, 10])
def wrap_multiple(eigenstate):
    DOS = eigenstate.DOS(E)
    PDOS = eigenstate.PDOS(E)
    return si.oplist([DOS, PDOS])
DOS, PDOS = mp.apply.average.eigenstate(wrap=wrap_multiple)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 6
#       4     PDOS = eigenstate.PDOS(E)
#       5     return si.oplist([DOS, PDOS])
# ----> 6 DOS, PDOS = mp.apply.average.eigenstate(wrap=wrap_multiple)
#
# File ~/miniconda3/envs/siesta-env/lib/python3.10/site-packages/sisl/physics/_brillouinzone_apply.py:458, in AverageApply.dispatch.<locals>.func(wrap, eta, *args, **kwargs)
#     453 eta.update()
#     454 for i, ki in enumerate(k[1:], 1):
#     455     v += (
#     456         _asoplist(
#     457             wrap(
# --> 458                 method(*args, k=ki, **kwargs),
#     459                 parent=parent,
#     460                 k=ki,
#     461                 weight=w[i],
#     462             )
#     463         )
#     464         * w[i]
#     465     )
#     466     eta.update()
#     467 eta.close()
#
# ...

# %%
E = np.linspace(-6, 6, 500)
bz = si.MonkhorstPack(H, [20, 20, 20])
dos = bz.apply.average.eigenvalue(wrap=lambda ev: ev.DOS(E))
plt.plot(E, dos)
plt.xlim(E[0], E[-1])
# Out:
# (-6.0, 6.0)

# %%
plt.plot(E, DOS, 'k', label="DOS")

# %%
# Define a function that plots the bandstructure and DOS together
def plotBandstructure2(formula):
    """Function to plot bandstructure and DOS for a given formula.
    Parameters:
    - formula: Chemical formula of the material.
    """
    sile_HSX = si.get_sile(f'bulk/relax/{formula}.HSX')
    H = sile_HSX.read_hamiltonian()
    geom = sile_HSX.read_geometry()
    Ef = sile_HSX.read_fermi_level()
    print("Fermi level (eV):", Ef)
    
    # Define tickmarks for the x- and y-axis
    ytickmarks = np.arange(-6, 8, 2)
    xtickmarks = np.arange(0, 7, 1)
    
    # Make a simple figure where graphs are plotted
    fig = plt.figure(figsize=[6.6, 5])

    # Subplot 1 - Band structure
    ax1 = fig.add_axes([0, 0, 1, 1])
    # Calculate band-structure using SISL
    band = si.BandStructure(geom, [ [0.0, 0.0, 0.0],     # Gamma
                                    [0.5, 0.0, 0.0],     # X
                                    [0.5, 0.5, 0.5],     # R
                                    [0.5, 0.5, 0.0],     # M
                                    [0.0, 0.0, 0.0],     # Gamma
                                    [0.5, 0.5, 0.5]      # R
                                    ], 301,              # number of k-points
                                    [r'$\Gamma$','X', 'R', 'M', r'$\Gamma$', 'R'])
    xtick, xtick_label = band.lineartick()
    lk = band.lineark()
    ax1.xaxis.set_ticks(xtick)
    ax1.set_xticklabels(xtick_label)

    # Plot vertical lines at symmetry points
    ax1.vlines(xtick, ytickmarks[0], ytickmarks[-1], color='0.5', linewidth=1)
    # Plot dashed line at Fermi level
    ax1.axhline(y=0, color='k', linestyle=':')

    # Plot band-structures
    band.set_parent(H)
    eigs = band.apply.ndarray.eigh()
    ax1.plot(lk, eigs, color='k')

    # Set x- and y-label
    ax1.set_xlabel('k-points')
    ax1.set_ylabel('Energy, $E-E_F$ (eV)')
    # Set x- and y-limits
    ax1.set_xlim(xtick[0], xtick[-1])
    ax1.set_ylim(ytickmarks[0], ytickmarks[-1])
    # Add minor tickmarks to the y-axis
    ax1.yaxis.set_minor_locator(AutoMinorLocator())
    
    # Subplot 2 - Density of states (DOS)
    ax2 = fig.add_axes([1.05, 0, 0.4, 1])
    # Calculate DOS using Monkhorst-Pack grid
    E = np.linspace(ytickmarks[0], ytickmarks[-1], 500)
    bz = si.MonkhorstPack(H, [40, 40, 40])
    dos = bz.apply.average.eigenvalue(wrap=lambda ev: ev.DOS(E))
    
    # Plot dashed line at Fermi level
    ax2.axhline(y=0, color='k', linestyle=':')
    
    # Plot total density of states
    ax2.plot(dos, E, 'k', label="DOS")
    
    # Customize y-axis label and other parameters if needed
    ax2.set_xlabel('DOS (1/eV)')
    # Force x- and y-ticks
    ax2.set_xticks(xtickmarks, xtickmarks)
    ax2.set_yticks(ytickmarks, ytickmarks)
    # Set limits to match
    ax2.set_xlim(xtickmarks[0], xtickmarks[-1])
    ax2.set_ylim(ytickmarks[0], ytickmarks[-1])
    # Hide y-tick labels
    ax2.set_yticklabels([])
    # Show figure
    plt.show()

# %%
plotBandstructure('BaTiO3')
# Out:
# Fermi level (eV): -7.29425339004041

# %%
plotBandstructure2('BaTiO3')
# Out:
# Fermi level (eV): -7.2945446055925816

# %% [markdown]
# <a id="phonons"></a>
# ## 5. Phonon dispersion (bulk)

# %% [markdown]
# We now move on to calculate the phonon dispersion. This is done with Phonopy using SIESTA as the calculator.

# %%
BaTiO3_rel = read('bulk/relax/BaTiO3.xyz')

# %%
calcPhonons(BaTiO3_rel, xcf='PBEsol', basis='DZP', cutoff=800, shift=0.008, kmesh=[3,3,3])
# Out:
# Generated 3 supercells with displacements.
# Processing supercell 1/3
# Job completed
# Processing supercell 2/3
# Job completed
# Processing supercell 3/3
# Job completed

# %%
from codes.phonons import plot_dispersion
import phonopy as ph

# %%
#phonon.write_animation()

# %%
phonon = ph.load(f'bulk/phonons/BaTiO3.yaml')
plot_dispersion(phonon)

# %%
phonon = ph.load(f'bulk/phonons/BaTiO3_pw_PBE.yaml')
plot_dispersion(phonon)

# %% [markdown]
# <a id="slabrelax"></a>
# ## 6. Slab relaxation

# %% [markdown]
# <a id="bandsslab"></a>
# ## 7. Band structure and phonons in slabs

# %% [markdown]
# ## Band structure calculation with SIESTA

# %%
calcBS('BaTiO3', xcf='PBE', basis='DZP', cutoff=200, shift=0.01)
# Out:
# Job completed

# %%
sile_bands = si.io.siesta.bandsSileSiesta('bulk/bandstructure/BaTiO3_BS.bands')

# %%
X, x, bands = sile_bands.read_data()
bands = np.squeeze(bands).T

# %%
fig, ax = plt.subplots(figsize=[6.6, 5])
ax.xaxis.set_ticks(X[0])
ax.set_xticklabels(X[1])

# Plot vertical lines at symmetry points
ax.vlines(X[0], -6, 6, color='0.5', linewidth=1)
# Plot dashed line at Fermi level
ax.axhline(y=0, color='k', linestyle=':')
for e_k in bands:
    ax.plot(x, e_k, lw=2, color='k')

# Set x- and y-label
ax.set_xlabel('k-points')
ax.set_ylabel('Energy, $E-E_F$ (eV)')
# Set x- and y-limits
ax.set_xlim(X[0][0], X[0][-1])
ax.set_ylim(-6, 6)
# Add minor tickmarks to the y-axis
ax.yaxis.set_minor_locator(AutoMinorLocator())
# Show the plot using tight layout
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Tests

# %%
Ef = sile_bands.read_fermi_level()
print(f'Fermi energy = {Ef} eV')
# Out:
# Fermi energy = -6.823540945946938 eV

# %%
sile_stdout = si.io.siesta.stdoutSileSiesta('bulk/relax/BaTiO3.out')

# %%
sile_stdout.read_stress()
# Out:
# array([[-0.00021,  0.     , -0.     ],
#        [ 0.     , -0.00021, -0.     ],
#        [-0.     , -0.     , -0.00021]])

# %%
sile_stdout.read_energy()
# Out:
# warn:0: SislWarning: Could not convert energy 'basis.enthalpy' (       -2221.979213 eV
# ) to a float, assigning nan.
# {'band': -500.552701,
#  'kinetic': 1213.797833,
#  'hartree': 404.564282,
#  'dftu': 0.0,
#  'spin_orbit': 0.0,
#  'extE': 0.0,
#  'exchange': -529.212544,
#  'correlation': -43.053052,
#  'bulkV': 0.0,
#  'xc': -572.265596,
#  'ion': {'electron': -1949.568405, 'ion': -1321.779507, 'kinetic': 0.0},
#  'D3 dispersion': 0.0,
#  'total': -2225.251392,
#  'fermi': -6.835263,
#  'basis': {'enthalpy': nan}}

# %%
sile_fdf = si.io.siesta.SileSiesta('bulk/relax/BaTiO3.fdf')

# %%
sile_HSX = si.io.siesta.hsxSileSiesta('bulk/relax/BaTiO3.HSX')

# %%
H = sile_HSX.read_hamiltonian()
geom = sile_HSX.read_geometry()

# %%
H = si.Hamiltonian.read('bulk/bandstructure/BaTiO3_BS.fdf')
geom = si.io.siesta.xvSileSiesta('bulk/bandstructure/BaTiO3_BS.XV').read_geometry()
#geom = si.io.siesta.stdoutSileSiesta.read_geometry(sile)
