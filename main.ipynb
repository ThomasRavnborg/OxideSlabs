# %% [markdown]
# # Main

# %%
# Importing libraries
import os
import numpy as np
import pandas as pd
import sisl as si
import phonopy as ph
import matplotlib.pyplot as plt
# ASE modules
from ase import Atoms
from ase.calculators.siesta import Siesta
from ase.units import Ry
from ase.visualize import view
from ase.io import read, write
from ase.dft.kpoints import bandpath
# Path module
from pathlib import Path
# Matplotlib ticker
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
# Custom modules
#from codes.bulkBS import calcBS, calcPDOS
from src.cleanfiles import cleanFiles
from src.utils import SiestaProject
from src.parameterconv import run_siesta, basis_opt, grid_conv
from src.structureoptimizer import perovskite, relax_ase, relax_siesta
from src.bandscalc import calculate_bands, plot_bands, plot_bands_SISL
from src.phononcalc import calculate_phonons, plot_dispersion
from src.plotsettings import PlotSettings
PlotSettings().set_global_style()

# %% [markdown]
# ## Contents
# This notebook contains the following sections:
# 1. [Basis set optimization](#basisset)
# 2. [Real-space grid optimization](#spacegrid)
# 3. [Structural optimization (bulk)](#structureopt)
# 4. [Band structure and DOS (bulk)](#bands)
# 5. [Phonon dispersion (bulk)](#phonons)

# %% [markdown]
# <a id="basisset"></a>
# ## 1. Basis set optimization

# %% [markdown]
# Although the default basis sets generated by SIESTA might be enough for some applications, we start by doing some optimization of the basis sets, which can help achieve better results with similar computational costs.

# %% [markdown]
# SIESTA uses atomic-centered basis sets (LCAO) on the form:
# \begin{equation*}
# \psi=R(r)Y_{ml}(\theta,\phi)
# \end{equation*}

# %%
BaTiO3 = perovskite('BaTiO3')

# %%
BaTiO3 = perovskite('BaTiO3')
view(BaTiO3)
# Out:
# <Popen: returncode: None args: ['/home/tbrav/miniconda3/envs/siesta-env/bin/...>

# %%
relax_ase(BaTiO3, xcf='PBEsol', basis='DZP', EnergyShift=0.01, SplitNorm=0.15,
          MeshCutoff=100, kgrid=(5, 5, 5), mode='pw', dir='gpaw_data/BaTiO3')
# Out:
# Relaxing structure for BaTiO3 using GPAW.
# Note that shift and split do not apply to pw calculations and will be ignored.
# Exception ignored in: <function GPAW.__del__ at 0x7d3a7c171fc0>
# Traceback (most recent call last):
#   File "/home/tbrav/miniconda3/envs/siesta-env/lib/python3.10/site-packages/gpaw/calculator.py", line 289, in __del__
#     self.close()
#   File "/home/tbrav/miniconda3/envs/siesta-env/lib/python3.10/site-packages/gpaw/calculator.py", line 295, in close
#     if hasattr(self, 'timer') and not self.log.fd.closed:
# AttributeError: 'NoneType' object has no attribute 'closed'

# %%
run_siesta(BaTiO3, xcf='PBEsol', basis='DZP', shift=0.01, split=0.15, cutoff=500, kmesh=[10, 10, 10])
# Out:
# Job completed

# %%
# Extract total Energy
stdsile = si.io.siesta.stdoutSileSiesta('results/bulk/basis/BaTiO3.out')
Energies = stdsile.read_energy()
Etot = Energies['total']
print(f'Total Energy: {Etot:.3f} eV')
# Extract Forces
FAsile = si.get_sile('results/bulk/basis/BaTiO3.FA')
Forces = FAsile.read_force()
max_force = max(np.linalg.norm(f) for f in Forces)
print(f'Maximum Force: {max_force} eV/Å')
# Extract lattice constants
xvsile = si.get_sile('results/bulk/basis/BaTiO3.XV')
lat = xvsile.read_geometry().lattice
a = lat.length[0]
b = lat.length[1]
c = lat.length[2]
print(f'Lattice Constants: a={a:.3f} Å, b={b:.3f} Å, c={c:.3f} Å')
# Extract bandgap at the Gamma point
eig = si.get_sile("results/bulk/basis/BaTiO3.EIG").read_data()
Ef = Energies['fermi']
eig -= Ef
eig = eig.flatten()
VBM = eig[eig <= 0].max()
CBM = eig[eig > 0].min()
bandgap = CBM - VBM
print(f'Bandgap at Gamma: {bandgap:.3f} eV')
# Out:
# Total Energy: -2218.815 eV
# Maximum Force: 9.657572050000634e-05 eV/Å
# Lattice Constants: a=4.010 Å, b=4.010 Å, c=4.010 Å
# Bandgap at Gamma: 5.981 eV
# warn:0: SislWarning: Could not convert energy 'basis.enthalpy' (       -2215.575651 eV
# ) to a float, assigning nan.

# %%
lat.length
# Out:
# array([4.01, 4.01, 4.01])

# %%
stdsile.read_energy()['total']
# Out:
# warn:0: SislWarning: Could not convert energy 'basis.enthalpy' (       -2215.575651 eV
# ) to a float, assigning nan.
# -2218.815468

# %%
si.get_sile(f'results/bulk/basis/BaTiO3.FA').read_force()
# Out:
# array([[ 9.65757205e-05,  7.35939567e-13, -3.50140997e-11],
#        [-4.51718455e-05, -2.11249479e-13,  2.78504844e-11],
#        [-7.20973492e-05,  7.55580724e-14,  1.34067071e-11],
#        [ 9.28747744e-05, -8.15714749e-15,  1.30330373e-11],
#        [-7.20973507e-05, -2.42457050e-14, -2.09631112e-11]])

# %%
si.io.siesta.structSileSiesta('results/bulk/basis/BaTiO3.STRUCT_OUT').read_geometry()
# Out:
# <sisl.Geometry na=5, no=5, nsc=[1 1 1]>

# %%
si.io.siesta.xvSileSiesta('results/bulk/basis/BaTiO3.XV').read_geometry().lattice
# Out:
# <sisl.Lattice a=4.01, b=4.01, c=4.01, α=90.0, β=90.0, γ=90.0, bc=[P, P, P], nsc=[1 1 1]>

# %%
sile = si.io.siesta.stdoutSileSiesta('results/bulk/basis/BaTiO3.out')
sile.read_energy()
# Out:
# warn:0: SislWarning: Could not convert energy 'basis.enthalpy' (       -2215.575651 eV
# ) to a float, assigning nan.
# {'band': -509.347213,
#  'kinetic': 1207.890484,
#  'hartree': 392.243231,
#  'dftu': 0.0,
#  'spin_orbit': 0.0,
#  'extE': 0.0,
#  'exchange': -517.845174,
#  'correlation': -47.696454,
#  'bulkV': 0.0,
#  'xc': -565.541628,
#  'ion': {'electron': -1930.324813, 'ion': -1323.082742, 'kinetic': 0.0},
#  'D3 dispersion': 0.0,
#  'total': -2218.815468,
#  'fermi': -7.20703,
#  'basis': {'enthalpy': nan}}

# %%
# This will run the basisoptimization script
# Note: This will take a long time to run on local, use cluster
#%run scripts/basis.py

# %%
df = pd.read_csv('results/bulk/basis/basisopt.csv', index_col=0)
df.head()
# Out:
#    Shift  Split     Enthalpy  MaxForce
# 0  0.001   0.01 -2217.987899  0.431084
# 1  0.001   0.05 -2219.463347  0.449341
# 2  0.001   0.10 -2219.991294  0.378782
# 3  0.001   0.15 -2220.082546  0.365684
# 4  0.001   0.20 -2220.064524  0.369930

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(7, 5))

for shift, data in df.groupby('Shift'):
    ax.plot(data['Split'], data['Enthalpy'], marker='o', label=f'Shift = {shift} Ry')

ax.set_xlabel('SplitNorm')
ax.set_ylabel('Basis Set Enthalpy (eV)')
#ax.set_title('Basis Set Enthalpy vs SplitNorm for Different Energy Shift Values')
ax.legend()
ax.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# %%
Z = df.pivot(index="Shift", columns="Split", values="Enthalpy")
X, Y = np.meshgrid(Z.columns.values, Z.index.values)
# Plotting the log-likelihood contour
fig = plt.figure(figsize=[6, 5])
ax = fig.add_subplot(111)
plt.title('Contour plot')
CS = ax.contour(X,Y,Z, 100, cmap='viridis')
fig.colorbar(CS, ax=ax)
# Add x- and y-labels
ax.set_xlabel('SplitNorm')
ax.set_ylabel('EnergyShift (Ry)')
# Set logarithmic scale for y-axis
ax.set_yscale('log')
# Show the plot using tight layout
plt.tight_layout()
plt.show()

# %%
from ase.calculators.siesta.parameters import Species, PAOBasisBlock

# %%
basis_set = PAOBasisBlock(
"""1
0  2 S 0.2
0.0 0.0""")

# %%
basis_set
# Out:
# {'block': '1\n    0  2 S 0.2\n    0.0 0.0'}

# %% [markdown]
# <a id="spacegrid"></a>
# ## 2. Real-space grid convergence

# %% [markdown]
# In SIESTA, the real-space grid underpins accuracy and efficiency. Choosing the right cutoff is crucial: too low, and you risk inaccurate results and spurious egg-box effects (variation of the total energy as atoms are displaced with respect to the integration grid); too high, and the calculation becomes unnecessarily expensive.

# %% [markdown]
# In this section, we perform mesh-cutoff convergence

# %%
# This will run the grid convergence script
# Note: This will take a long time to run on local, use cluster
#%run scripts/grid.py

# %%
df = pd.read_csv('results/bulk/grid/gridopt.csv', index_col=0)
#df = df[df["MeshCutoff"]>=100]
df.head()
# Out:
#    MeshCutoff  KPoints     Enthalpy  MaxForce
# 0         100        5 -2222.047309  0.347548
# 1         100       10 -2222.055626  0.349204
# 2         100       15 -2222.055728  0.349292
# 3         100       20 -2222.055731  0.349309
# 4         200        5 -2221.936557  0.348383

# %%
fig, ax = plt.subplots(figsize=(7, 5))

for k, data in df.groupby('KPoints'):
    ax.plot(data['MeshCutoff'], data['Enthalpy'], marker='o', label=f'KPoints = {k}x{k}x{k}')

ax.set_xlabel('Mesh Cutoff (Ry)')
ax.set_ylabel('Basis Set Enthalpy (eV)')
#ax.set_title('Basis Set Enthalpy vs SplitNorm for Different Energy Shift Values')
ax.legend()
ax.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(7, 5))

for k, data in df.groupby('KPoints'):
    ax.plot(data['MeshCutoff'], data['MaxForce'], marker='o', label=f'KPoints = {k}x{k}x{k}')

ax.set_xlabel('Mesh Cutoff (Ry)')
ax.set_ylabel('Max Force (eV/Å)')
#ax.set_title('Basis Set Enthalpy vs SplitNorm for Different Energy Shift Values')
ax.legend()
ax.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# %% [markdown]
# <a id="structureopt"></a>
# ## 3. Structural optimization (bulk)

# %% [markdown]
# First we run a relaxation script where we let ASE handle position and cell optimization:

# %%
BaTiO3 = perovskite('BaTiO3')

# %%
import os
print(os.environ["GPAW_SETUP_PATH"])
# Out:
# /home/tbrav/projects/OxideSlabs/gpaw_data

# %%
import os
print("GPAW_SETUP_PATH" in os.environ)
# Out:
# True

# %%
#relax_ase(BaTiO3, xcf='PBEsol', basis='DZP', cutoff=50, kmesh=[5, 5, 5], mode='pw')
# Out:
# Relaxing structure for BaTiO3 using GPAW.
# Note that shift and split do not apply to pw calculations and will be ignored.

# %%
atoms = read('results/bulk/relax/BaTiO3_pw.xyz')

# %%
atoms.get_cell()
# Out:
# Cell([[3.9722942659050537, -4.988446121833947e-16, 9.683073650042079e-38], [2.3043676293015934e-16, 3.9722942659050537, 3.0320810957729004e-39], [-5.562808803719362e-20, 4.7979131734332665e-35, 3.972294265905053]])

# %%
atoms.get_positions()
# Out:
# array([[ 0.        , -0.        , -0.        ],
#        [ 1.98614713,  1.98614713,  1.98614713],
#        [ 1.98614713, -0.        ,  1.98614713],
#        [ 0.        ,  1.98614713,  1.98614713],
#        [ 1.98614713,  1.98614713, -0.        ]])

# %% [markdown]
# The following function runs a single Siesta calculation which includes relaxation:

# %%
#relax_siesta(BaTiO3, xcf='PBEsol', basis='DZP', cutoff=200, shift=0.008, kmesh=[5, 5, 5])
# Out:
# Job completed

# %%
atoms = read('results/bulk/relaxsiesta/BaTiO3.xyz')
atoms.get_cell()
# Out:
# Cell([[4.01921105446119, -0.0, 0.0], [-0.0, 4.019211327516631, 5.29177210903e-10], [0.0, 5.29177210903e-10, 4.019210282920817]])

# %%
atoms.get_positions()
# Out:
# array([[-0.00000000e+00,  0.00000000e+00, -4.00000000e-08],
#        [ 2.00960553e+00,  2.00960566e+00,  2.00960527e+00],
#        [ 2.00960553e+00,  0.00000000e+00,  2.00960516e+00],
#        [-0.00000000e+00,  2.00960566e+00,  2.00960522e+00],
#        [ 2.00960553e+00,  2.00960566e+00,  5.00000000e-07]])

# %% [markdown]
# <a id="bands"></a>
# ## 4. Band structure and DOS (bulk)

# %% [markdown]
# The band structure can be calculated using either SIESTA or SISL.
# The easiest is to use SISL, which can extract the Hamiltonian and geometry from the generated .HSX file:

# %%
# Read relaxed structures
#BaTiO3_rel = read('bulk/relax/BaTiO3.xyz')
# Calculate band structure and PDOS
# Here commented out to avoid long computation, use cluster
#calculate_bands(BaTiO3, xcf='PBEsol', basis='DZP', cutoff=1200, shift=0.008, kmesh=[10, 10, 10])

# %%
plot_bands('BaTiO3')
# Out:
# Fermi level (eV): -7.1936661890004405

# %%
plot_bands_SISL('BaTiO3')
# Out:
# Fermi level (eV): -7.20623457290124

# %%
plot_bands('SrTiO3')
# Out:
# Fermi level (eV): -6.833649742175734
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 plot_bands('SrTiO3')
#
# File ~/projects/OxideSlabs/src/bandscalc.py:130, in plot_bands(formula)
#     127 # Subplot 2 - Density of states (DOS)
#     128 # Read the PDOS data from the file generated by Siesta using SISL
#     129 sile_PDOS = si.get_sile(f'{dir}{formula}.PDOS')
# --> 130 geom, E, PDOS = sile_PDOS.read_data()
#     131 PDOS = np.squeeze(PDOS)
#     133 # Create a new axes object for the DOS plot
#
# File ~/miniconda3/envs/siesta-env/lib/python3.10/site-packages/sisl/io/sile.py:772, in sile_fh_open.<locals>._wrapper.<locals>.pre_open(self, *args, **kwargs)
#     770 @wraps(func)
#     771 def pre_open(self, *args, **kwargs):
# --> 772     with self:
#     773         # This happens when the file seeks to 0,
#     774         # so basically the same as re-opening the file
#     775         reset(self)
#     776         return func(self, *args, **kwargs)
#
# File ~/miniconda3/envs/siesta-env/lib/python3.10/site-packages/sisl/io/sile.py:1364, in Sile.__enter__(self)
#    1362 def __enter__(self):
#    1363     """Opens the output file and returns it self"""
# -> 1364     self._open()
#    1365     return self
#
# File ~/miniconda3/envs/siesta-env/lib/python3.10/site-packages/sisl/io/sile.py:1355, in Sile._open(self)
#    1353             self.fh = gzip.open(str(self.file), mode=self._mode)
#    1354     else:
# -> 1355         self.fh = self.file.open(self._mode)
#    1357 # the file should restart the file-read (as per instructed)
#    1358 self._line = 0
#
# File ~/miniconda3/envs/siesta-env/lib/python3.10/pathlib.py:1119, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1117 if "b" not in mode:
#    1118     encoding = io.text_encoding(encoding)
# -> 1119 return self._accessor.open(self, mode, buffering, encoding, errors,
#    1120                            newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'results/bulk/bandstructure/SrTiO3.PDOS'

# %%
plot_bands_SISL('SrTiO3')
# Out:
# Fermi level (eV): -7.167091698342832

# %% [markdown]
# <a id="phonons"></a>
# ## 5. Phonon dispersion (bulk)

# %% [markdown]
# We now move on to calculate the phonon dispersion. This is done with Phonopy using SIESTA as the calculator.

# %%
# Read relaxed structures
#BaTiO3 = read('bulk/relax/BaTiO3.xyz')
#SrTiO3 = read('bulk/relax/SrTiO3.xyz')
# Calculate phonon dispersion
# Here commented out to avoid long computation, use cluster
#calculate_phonons(BaTiO3, xcf='PBEsol', basis='DZP', cutoff=1200, shift=0.008, kmesh=[5, 5, 5])

# %%
#phonon.write_animation()

# %%
phonon = ph.load(f'results/bulk/phonons/BaTiO3_phonon.yaml')
plot_dispersion(phonon)

# %%
phonon = ph.load(f'results/bulk/phonons/BaTiO3.yaml')
plot_dispersion(phonon)

# %%
phonon = ph.load(f'results/bulk/phonons/BaTiO3_pw_PBE.yaml')
plot_dispersion(phonon)

# %%
phonon = ph.load(f'results/bulk/phonons/SrTiO3_phonon.yaml')
plot_dispersion(phonon)

# %% [markdown]
# <a id="slabrelax"></a>
# ## 6. Slab relaxation

# %% [markdown]
# <a id="bandsslab"></a>
# ## 7. Band structure and phonons in slabs

# %% [markdown]
# ## Tests

# %%
# Define lists of parameters to iterate over
xcfs =    ['PBEsol']
basis =   ['DZP']
shifts =  [0.008, 0.01, 0.012]
splits =  [0.1, 0.15, 0.2]
cutoffs = [800, 1000]
grids =   [10]

# %%
# Find all combinations of parameters and store in a list of dictionaries
from itertools import product
combinations = list(product(xcfs, basis, shifts, splits, cutoffs, grids))
print(f"Total combinations: {len(combinations)}")
param_dicts = []
for combo in combinations:
    param_dicts.append({
        'xcf': combo[0],
        'basis': combo[1],
        'EnergyShift': combo[2],
        'SplitNorm': combo[3],
        'MeshCutoff': combo[4],
        'kgrid': (combo[5], combo[5], combo[5])
    })
# Out:
# Total combinations: 18

# %%
from src.structureoptimizer import perovskite, relax_ase
# Create atoms object for BaTiO3 and SrTiO3
atoms = perovskite('BaTiO3')
from src.utils import SiestaProject
project = SiestaProject(material=str(atoms.symbols))

params = {
    'xcf': 'PBEsol',
    'basis': 'DZP',
    "EnergyShift": 0.01,
    "SplitNorm": 0.15,
    "MeshCutoff": 400,
    "kgrid": (5, 5, 5)
}

# %%
calc_id = project.prepare_calculation(params)
next_step = project.what_to_run(calc_id)
dir = os.path.join(project.material_path, calc_id)
print(f"Next step: {next_step}")
print(dir)
# Out:
# Next step: complete
# results/bulk/BaTiO3/0001

# %%
calc_id = project.prepare_calculation(params)
next_step = project.what_to_run(calc_id)
dir = os.path.join(project.material_path, calc_id)

if next_step == "relax":
    # Run relaxation
    print(f"Running relaxation for calculation {calc_id}")
    relax_ase(atoms, **params, dir=os.path.join(dir, next_step))
    # Update dataframe and move to next step
    calc_id = project.prepare_calculation(params)
    next_step = project.what_to_run(calc_id)

if next_step == "bands":
    # Run band structure calculation
    print(f"Running band structure calculation for calculation {calc_id}")
    atoms = read(os.path.join(dir, 'relax', f'{project.material}.xyz'))
    calculate_bands(atoms, **params, dir=os.path.join(dir, next_step))
    # Update to next step
    calc_id = project.prepare_calculation(params)
    next_step = project.what_to_run(calc_id)

if next_step == "phonons":
    print(f"Running phonon calculation for calculation {calc_id}")
    atoms = read(os.path.join(dir, 'relax', f'{project.material}.xyz'))
    calculate_phonons(atoms, **params, dir=os.path.join(dir, next_step))
    # Update to next step
    calc_id = project.prepare_calculation(params)
    next_step = project.what_to_run(calc_id)

if next_step == "complete":
    print(f"All steps complete for calculation {calc_id}. Skipping.")
# Out:
# All steps complete for calculation 0001. Skipping.

# %%
project.what_to_run('0001')
# Out:
# 'complete'

# %%
project.get_summary()
# Out:
#      ID     xcf basis EnergyShift SplitNorm MeshCutoff      kgrid relax bands  \
# 0  0001  PBEsol   DZP     0.01 Ry      0.15     400 Ry  (5, 5, 5)     ✓     ✓
# 1  0002  PBEsol   DZP     0.01 Ry      0.15     500 Ry  (5, 5, 5)     ✓     ✗
#
#   phonons
# 0       ✓
# 1       ✗

# %%
project.remove_calculation("0005")
# Out:
# [0002] Folder does not exist.
# [0002] Not found in summary CSV.

# %%
project = SiestaProject(material='BaTiO3')

# %%
df = project.get_summary()
df.head()
# Out:
#      ID     xcf basis EnergyShift SplitNorm MeshCutoff         kgrid relax  \
# 0  0001  PBEsol   DZP    0.008 Ry       0.1     800 Ry  (10, 10, 10)     ✓
# 1  0002  PBEsol   DZP    0.008 Ry       0.1    1000 Ry  (10, 10, 10)     ✓
# 2  0003  PBEsol   DZP    0.008 Ry      0.15     800 Ry  (10, 10, 10)     ✓
# 3  0004  PBEsol   DZP    0.008 Ry      0.15    1000 Ry  (10, 10, 10)     ✓
# 4  0005  PBEsol   DZP    0.008 Ry       0.2     800 Ry  (10, 10, 10)     ✓
#
#   bands phonons
# 0     ✓       ✓
# 1     ✓       ✓
# 2     ✓       ✓
# 3     ✓       ✓
# 4     ✓       ✓

# %%
rdf = df[(df['SplitNorm'] == '0.15') & (df['MeshCutoff'] == '1000 Ry') & (df['kgrid'] == '(10, 10, 10)')]
rdf = rdf.sort_values(by='EnergyShift')
ids = rdf['ID']
shifts = rdf['EnergyShift']
rdf
# Out:
#       ID     xcf basis EnergyShift SplitNorm MeshCutoff         kgrid relax  \
# 20  0021  PBEsol   DZP    0.004 Ry      0.15    1000 Ry  (10, 10, 10)     ✓
# 26  0027  PBEsol   DZP    0.006 Ry      0.15    1000 Ry  (10, 10, 10)     ✓
# 3   0004  PBEsol   DZP    0.008 Ry      0.15    1000 Ry  (10, 10, 10)     ✓
# 9   0010  PBEsol   DZP     0.01 Ry      0.15    1000 Ry  (10, 10, 10)     ✓
# 15  0016  PBEsol   DZP    0.012 Ry      0.15    1000 Ry  (10, 10, 10)     ✓
#
#    bands phonons
# 20     ✓       ✓
# 26     ✓       ✓
# 3      ✓       ✓
# 9      ✓       ✓
# 15     ✓       ✓

# %%
plot_bands('BaTiO3', ids=ids)

# %%
plot_dispersion('BaTiO3', ids=ids, pDOS=False)

# %%
# Plot lattice constants for a set of IDs

atoms_pw = read('gpaw_data/BaTiO3/BaTiO3.xyz')
cell_pw = atoms_pw.get_cell()
print(cell_pw[0, 0])

lats = []
for calc_id in ids:
    atoms = read(f'results/bulk/BaTiO3/{calc_id}/relax/BaTiO3.xyz')
    cell = atoms.get_cell()
    a = cell[0, 0]
    b = cell[1, 1]
    c = cell[2, 2]
    lats.append((a, b, c))

plt.figure(figsize=(7, 5))
a_values = [lat[0] for lat in lats]
b_values = [lat[1] for lat in lats]
c_values = [lat[2] for lat in lats]
plt.plot(shifts, a_values, marker='o', label='a (Å)')
plt.plot(shifts, b_values, marker='o', label='b (Å)')
plt.plot(shifts, c_values, marker='o', label='c (Å)')
plt.legend()
plt.xlabel('Energy Shift (eV)')
plt.ylabel('Lattice Constant (Å)')
plt.title('Lattice Constants for Different Energy Shifts')
plt.show()
# Out:
# 3.983539832693191

# %%
atoms_pw = read('gpaw_data/BaTiO3.xyz')
cell = atoms_pw.get_cell()

# %%
cell[0, 0]
cell[1, 1]
cell[2, 2]
# Out:
# np.float64(3.972294265905053)

# %%
atoms_ase = read('results/bulk/relax/BaTiO3.xyz')
atoms_ase.get_cell()
# Out:
# Cell([[4.019612628545467, 0.0, 0.0], [-2.182621886239049e-19, 4.019612628545467, 0.0], [0.0, 0.0, 4.019612628545467]])

# %%
atoms_siesta = read('results/bulk/relaxsiesta/BaTiO3.xyz')
atoms_siesta.get_cell()
# Out:
# Cell([[4.01363784156925, -1.3758607483478e-08, 2.116708843612e-09], [-1.3758607483478e-08, 4.013637795530832, 9.525189796253999e-09], [2.116708843612e-09, 9.525189796253999e-09, 4.0136378775533]])
